# %%
import yfinance as yf
import pandas as pd

# %%
msft = yf.Ticker("MSFT")

# %%
msft.options
# Out:
# ('2023-10-06',
#  '2023-10-13',
#  '2023-10-20',
#  '2023-10-27',
#  '2023-11-03',
#  '2023-11-10',
#  '2023-11-17',
#  '2023-12-15',
#  '2024-01-19',
#  '2024-02-16',
#  '2024-03-15',
#  '2024-04-19',
#  '2024-05-17',
#  '2024-06-21',
#  '2024-09-20',
#  '2024-12-20',
#  '2025-01-17',
#  '2025-06-20',
#  '2025-12-19',
#  '2026-01-16')

# %%
calls = msft.option_chain(msft.options[0]).calls
puts = msft.option_chain(msft.options[0]).puts

# %%
df = pd.concat([calls, puts], axis=0)

# %%
df
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   MSFT231006C00170000 2023-10-04 16:57:57+00:00   170.0     149.60  147.05
# 1   MSFT231006C00215000 2023-09-28 15:23:16+00:00   215.0      97.30  102.50
# 2   MSFT231006C00220000 2023-09-13 17:44:37+00:00   220.0     117.65   97.05
# 3   MSFT231006C00225000 2023-09-29 15:56:43+00:00   225.0      93.00   92.40
# 4   MSFT231006C00230000 2023-09-27 17:48:09+00:00   230.0      80.70   87.60
# ..                  ...                       ...     ...        ...     ...
# 51  MSFT231006P00395000 2023-09-20 19:37:09+00:00   395.0      72.91   73.80
# 52  MSFT231006P00410000 2023-08-25 16:15:03+00:00   410.0      89.18   91.00
# 53  MSFT231006P00420000 2023-08-25 16:11:08+00:00   420.0      99.52  101.00
# 54  MSFT231006P00460000 2023-09-20 17:03:45+00:00   460.0     133.59  139.05
# 55  MSFT231006P00470000 2023-09-12 15:39:41+00:00   470.0     136.99  149.20
#
# ...
